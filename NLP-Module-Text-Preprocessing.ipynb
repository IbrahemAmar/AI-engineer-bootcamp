# %%
##Lower casting text

# %%
sentence = "Her cat's name is Luna"

# %%
lower_sentence = sentence.lower()

# %%
print(lower_sentence)
# Out:
# her cat's name is luna

# %%
##Removing stopwords

# %%
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\abrah\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
en_stopwords = stopwords.words('english')

# %%
print(en_stopwords)
# Out:
# ['a', 'about', 'above', 'after', 'again', 'against', 'ain', 'all', 'am', 'an', 'and', 'any', 'are', 'aren', "aren't", 'as', 'at', 'be', 'because', 'been', 'before', 'being', 'below', 'between', 'both', 'but', 'by', 'can', 'couldn', "couldn't", 'd', 'did', 'didn', "didn't", 'do', 'does', 'doesn', "doesn't", 'doing', 'don', "don't", 'down', 'during', 'each', 'few', 'for', 'from', 'further', 'had', 'hadn', "hadn't", 'has', 'hasn', "hasn't", 'have', 'haven', "haven't", 'having', 'he', "he'd", "he'll", 'her', 'here', 'hers', 'herself', "he's", 'him', 'himself', 'his', 'how', 'i', "i'd", 'if', "i'll", "i'm", 'in', 'into', 'is', 'isn', "isn't", 'it', "it'd", "it'll", "it's", 'its', 'itself', "i've", 'just', 'll', 'm', 'ma', 'me', 'mightn', "mightn't", 'more', 'most', 'mustn', "mustn't", 'my', 'myself', 'needn', "needn't", 'no', 'nor', 'not', 'now', 'o', 'of', 'off', 'on', 'once', 'only', 'or', 'other', 'our', 'ours', 'ourselves', 'out', 'over', 'own', 're', 's', 'same', 'shan', "shan't", 's
# ...

# %%
sentence = 'Although the weather was quite cold and windy, the students decided to continue their outdoor project because they believed it would help them learn better.'

# %%
sentence_no_stopwords = ' '.join([word for word in sentence.split() if word not in en_stopwords])

# %%
print(sentence_no_stopwords)
# Out:
# Although weather quite cold windy, students decided continue outdoor project believed would help learn better.

# %%
en_stopwords.remove("the")
en_stopwords.append("Although")

# %%
sentence_no_stopwords_custom = ' '.join([word for word in sentence.split() if word not in en_stopwords])

# %%
print(sentence_no_stopwords_custom)
# Out:
# the weather quite cold windy, the students decided continue outdoor project believed would help learn better.

# %%
##Regular expressions (regex)

# %%
import re

# %%
my_folder = "C\desktop\notes"
print(my_folder)
# Out:
# C\desktop
# otes

# %%
my_folder_raw = r"C\desktop\notes"
print(my_folder_raw)
# Out:
# C\desktop\notes

# %%
result_search = re.search("pattern", r"string to contain the pattern")
print(result_search)
# Out:
# <re.Match object; span=(22, 29), match='pattern'>

# %%
result_search = re.search("pattern", r"string do not contain")
print(result_search)
# Out:
# None

# %%
string = "sara was able to help me find the items i needed quickly"

# %%
new_string = re.sub("sara","sarah",string)

# %%
print(new_string)
# Out:
# sarah was able to help me find the items i needed quickly

# %%
customer_reviews = ['sam was a great help to me in the store', 
 'the cashier was very rude to me, I think her name was eleanor', 
 'amazing work from sadeen!', 
 'sarah was able to help me find the items i needed quickly', 
 'lucy is such a great addition to the team', 
 'great service from sara she found me what i wanted']

# %%
sarahs_reviews = []

# %%
pattern_to_find = r"sarah?"

# %%
for string in customer_reviews:
    if (re.search(pattern_to_find, string)):
        sarahs_reviews.append(string)

# %%
print(sarahs_reviews)
# Out:
# ['sarah was able to help me find the items i needed quickly', 'great service from sara she found me what i wanted']
